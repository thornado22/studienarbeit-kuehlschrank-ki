# %%
from stats import plot_confusion_matrix_from_json, plot_metric_barchart_from_json, plot_f1

# %%
plot_f1(["butter_magarine", "sahne"], [0.6111, 0.3415],  "Test-Klassen-F1-Scores aus Test Single-Label", "test_f1_single")
plot_f1(["butter_magarine", "sahne"], [0.6990, 0.407],  "Validierungs-Klassen-F1-Scores aus Test Single-Label", "f1_single")
# Out:
# c:\Users\Nelly\Documents\Programmieren\kuehlscharnkKI\backend\computerVision\stats\stats.py:95: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=x, y=y, palette=palette)
# c:\Users\Nelly\Documents\Programmieren\kuehlscharnkKI\backend\computerVision\stats\stats.py:95: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=x, y=y, palette=palette)

# %%
json = "../eval/test_two_1/per_class_confusion.json"

# %%
plot_confusion_matrix_from_json(json, "Testdaten Test Verkettet", "cm_test_two_1")
# Out:
# (<Figure size 550x450 with 2 Axes>,
#  <Axes: title={'center': 'Confusion Matrix für Testdaten Test Verkettet'}>)

# %%
plot_metric_barchart_from_json(json, title="Test-Klassen-F1-Scores aus Test Verkettet", save_path="test_f1_test_two_1")
# Out:
# (<Figure size 600x550 with 1 Axes>,
#  <Axes: title={'center': 'Test-Klassen-F1-Scores aus Test Verkettet'}, xlabel='Label', ylabel='F1'>)

# %%
import json
file = "../models/test_two_1.json"

with open(file, "r") as f:
    src = json.load(f)

val_class_f1 = src["results"]["val_class_f1"]
classes = src["meta"]["classes"]

plot_f1( classes, val_class_f1, "Test 3", "f1_test_two_1.png")
# Out:
# c:\Users\Nelly\Documents\Programmieren\kuehlscharnkKI\backend\computerVision\stats\stats.py:95: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=x, y=y, palette=palette)
