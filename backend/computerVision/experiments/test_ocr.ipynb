# %%
image1 = "1KEbIIIvCPfvUhtx-w1YEzDHtnjeipDrY.jpg"
image2 = "1ls2gDnH_WnkO0f_kGm5J7if4cUIJE2Tb.jpg"
image3 = "1ojwGumA2on2Kel85RbpPhTf1F8J7B2KK.jpg"
image4 = "1SbHXN5oyOAyZKmLf2pfBCSgPG3lOitdr.jpg"
image5= "1UmnzkQvKG0Zzat3rejl0fGxxSILVjzr7.jpg"

# %%
import easyocr

reader = easyocr.Reader(['de'])
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
results = reader.readtext(image2)

for bbox, text, conf in results:
    if conf > 0.5:
        print(text)
# Out:
# c:\Users\Z0246412\kuehlscharnkKI\.venv\Lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# 2
# 1
# liBr hmbutter
# loge
# 0
# <
# 2
# ;
# 37256
# 112925
# |
# 5
# 8
# 1
# 1
# 1
# |
# 27.11.25
# 1
